# %% [markdown]
# <a href="https://colab.research.google.com/github/quvonchbekaxmedov21-cloud/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
mydataset = {
    'cars': ["BMW", "Volvo", "Ford", "BMW", "Volvo", "Ford"],
    'counts': [3, 7, 2, 3, 7, 2]
}

print(mydataset)
print('========')

df = pd.DataFrame(mydataset)
print(df)
# Out:
# {'cars': ['BMW', 'Volvo', 'Ford', 'BMW', 'Volvo', 'Ford'], 'counts': [3, 7, 2, 3, 7, 2]}
# ...
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3    BMW       3
# 4  Volvo       7
# 5   Ford       2

# %%
df.head()   # default 5 rows
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3    BMW       3
# 4  Volvo       7

# %%
df.tail()   # counts 5 from the last
# Out:
#     cars  counts
# 1  Volvo       7
# 2   Ford       2
# 3    BMW       3
# 4  Volvo       7
# 5   Ford       2

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.shape
# Out:
# (6, 2)

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
df.describe()
# Out:
#          counts
# count  6.000000
# mean   4.000000
# std    2.366432
# min    2.000000
# 25%    2.250000
# 50%    3.000000
# 75%    6.000000
# max    7.000000

# %%
print(df)
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3    BMW       3
# 4  Volvo       7
# 5   Ford       2

# %%
df.describe(include='all')
# Out:
#        cars    counts
# count     6  6.000000
# unique    3       NaN
# top     BMW       NaN
# freq      2       NaN
# mean    NaN  4.000000
# std     NaN  2.366432
# min     NaN  2.000000
# 25%     NaN  2.250000
# 50%     NaN  3.000000
# 75%     NaN  6.000000
# max     NaN  7.000000

# %%
df.iloc[0]
# Out:
# cars      BMW
# counts      3
# Name: 0, dtype: object

# %%
df.loc[2:4, "cars"]
# Out:
# 2     Ford
# 3      BMW
# 4    Volvo
# Name: cars, dtype: object

# %%
df.sum()
# Out:
# cars      BMWVolvoFordBMWVolvoFord
# counts                          24
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      2
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# counts    4.0
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# counts    2.366432
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", "None", "Tesla", "Ferrari", "None", "Ford"],
    "counts": [3, 7, None, 8, 1, 9, None]
}

df_missing = pd.DataFrame(data_with_missing)

print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      0
# counts    2
# dtype: int64

# %%
df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %%
df.to_excel("titanic.xlsx")
